# %% [markdown]
# Monolingual (en, zh, mixed)

# %%
from IPython.display import Audio
import soundfile as sf

from models import GibbsTTS
from config import ModelConfig
configs = ModelConfig()
model = GibbsTTS(configs)

# Inference configs can be changed here or in the config.py
# model.configs.steps = 32
# model.configs.speed = 1.
# model.configs.cfg = 2.5
# model.configs.rescale_cfg = 0.75
# model.configs.temperature = 0.6
# model.configs.top_p = 1.

# %%
# English
prompt_audio = "./prompt_examples/common_voice_en_188092-common_voice_en_188093.wav"
prompt_text = "This man looked exactly the same, except that now the roles were reversed."
target_text = "He also tried to remember some good stories to relate as he sheared the sheep."
prompt_lang = "en"
target_lang = "en"

audio = model.synthesize(prompt_audio=prompt_audio, prompt_text=prompt_text, target_text=target_text, prompt_lang=prompt_lang, target_lang=target_lang)
# sf.write(f'target.wav', audio, 24000, 'PCM_24')
Audio(data=audio, rate=24000)

# %%
# Chinese Mandarin
prompt_audio = "./prompt_examples/00005476-00000047.wav"
prompt_text = "该委员会的角色，类似新总统的亲友团或后援团。"
target_text = "上发条的弹簧钟发明之前，没有准点时间来确保远程航行的安全。"
prompt_lang = "zh"
target_lang = "zh"

audio = model.synthesize(prompt_audio=prompt_audio, prompt_text=prompt_text, target_text=target_text, prompt_lang=prompt_lang, target_lang=target_lang)
# sf.write(f'target.wav', audio, 24000, 'PCM_24')
Audio(data=audio, rate=24000)

# %%
# English/Chinese mixing:
# A very small proportion of the training data consists of mixed English-Chinese sentences, labeled as `mixed`. 
# This helps the model better synthesize sentences containing both English and Chinese.
prompt_audio = "./prompt_examples/common_voice_en_188092-common_voice_en_188093.wav"
prompt_text = "This man looked exactly the same, except that now the roles were reversed."
target_text = "我做完这个pre，你帮我download点document。O不OK？"
prompt_lang = "en"
target_lang = "mixed"

audio = model.synthesize(prompt_audio=prompt_audio, prompt_text=prompt_text, target_text=target_text, prompt_lang=prompt_lang, target_lang=target_lang)
# sf.write(f'target.wav', audio, 24000, 'PCM_24')
Audio(data=audio, rate=24000)

# %% [markdown]
# Cross-lingual (en, zh, mixed)

# %%
prompt_audio = "./prompt_examples/common_voice_en_188092-common_voice_en_188093.wav"
prompt_text = "This man looked exactly the same, except that now the roles were reversed."
target_text = "上发条的弹簧钟发明之前，没有准点时间来确保远程航行的安全。"
prompt_lang = "en"
target_lang = "zh"

audio = model.synthesize(prompt_audio=prompt_audio, prompt_text=prompt_text, target_text=target_text, prompt_lang=prompt_lang, target_lang=target_lang)
# sf.write(f'target.wav', audio, 24000, 'PCM_24')
Audio(data=audio, rate=24000)

# %%
# Chinese Mandarin
prompt_audio = "./prompt_examples/00005476-00000047.wav"
prompt_text = "该委员会的角色，类似新总统的亲友团或后援团。"
target_text = "He also tried to remember some good stories to relate as he sheared the sheep."
prompt_lang = "zh"
target_lang = "en"

audio = model.synthesize(prompt_audio=prompt_audio, prompt_text=prompt_text, target_text=target_text, prompt_lang=prompt_lang, target_lang=target_lang)
# sf.write(f'target.wav', audio, 24000, 'PCM_24')
Audio(data=audio, rate=24000)

# %% [markdown]
# Japanese synthesis (LoRA fine-tuned)

# %%
from IPython.display import Audio
import soundfile as sf

from models import GibbsTTS
from config import ModelConfig, LoRAConfig
configs = ModelConfig()
configs.lora = LoRAConfig()
model = GibbsTTS(configs)

# Inference configs can be changed here or in the config.py
# model.configs.steps = 32
# model.configs.speed = 1.
# model.configs.cfg = 2.5
# model.configs.rescale_cfg = 0.75
# model.configs.temperature = 0.6
# model.configs.top_p = 1.

# %%
prompt_audio = "./prompt_examples/prompt_audio_1.wav"
prompt_text = "この料理は家庭で作れます。"
target_text = "アラバマ州の最大都市はバーミングハムである"
prompt_lang = "ja"
target_lang = "ja"

audio = model.synthesize(prompt_audio=prompt_audio, prompt_text=prompt_text, target_text=target_text, prompt_lang=prompt_lang, target_lang=target_lang)
# sf.write(f'target.wav', audio, 24000, 'PCM_24')
Audio(data=audio, rate=24000)

# %%
prompt_audio = "./prompt_examples/common_voice_en_188092-common_voice_en_188093.wav"
prompt_text = "This man looked exactly the same, except that now the roles were reversed."
target_text = "アラバマ州の最大都市はバーミングハムである"
prompt_lang = "en"
target_lang = "ja"

audio = model.synthesize(prompt_audio=prompt_audio, prompt_text=prompt_text, target_text=target_text, prompt_lang=prompt_lang, target_lang=target_lang)
# sf.write(f'target.wav', audio, 24000, 'PCM_24')
Audio(data=audio, rate=24000)

# %%
prompt_audio = "./prompt_examples/00005476-00000047.wav"
prompt_text = "该委员会的角色，类似新总统的亲友团或后援团。"
target_text = "アラバマ州の最大都市はバーミングハムである"
prompt_lang = "zh"
target_lang = "ja"

audio = model.synthesize(prompt_audio=prompt_audio, prompt_text=prompt_text, target_text=target_text, prompt_lang=prompt_lang, target_lang=target_lang)
# sf.write(f'target.wav', audio, 24000, 'PCM_24')
Audio(data=audio, rate=24000)
